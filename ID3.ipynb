# %% [markdown]
# <a href="https://colab.research.google.com/github/SreeBhagya-S/TKM_21/blob/main/ID3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/dataset.csv")
print("\n Given Play Golf Dataset:\n\n", df)
# Out:
#  Given Play Golf Dataset:
#
#     Age Salary Job Performance Select
# 0    Y      H   P           A      N
# 1    Y      H   P           E      N
# 2    M      H   P           A      Y
# 3    O      M   P           A      Y
# 4    O      L   G           A      Y
# 5    O      L   G           E      N
# 6    M      L   G           E      Y
# 7    Y      M   P           A      N
# 8    Y      L   G           A      Y
# 9    O      M   G           A      Y
# 10   Y      M   G           E      Y
# 11   M      M   P           E      Y
# 12   M      H   G           A      Y
# 13   O      M   P           E      N

# %%
t = df.keys()[-1]
print('Target Attribute is   ➡ ', t)

# Get the attribute names from input dataset
attribute_names = list(df.keys())

#Remove the target attribute from the attribute names list
attribute_names.remove(t) 

print('Predicting Attributes ➡ ', attribute_names)
# Out:
# Target Attribute is   ➡  Select
# Predicting Attributes ➡  ['Age', 'Salary', 'Job', 'Performance']

# %%
#Function to calculate the entropy of probaility of observations
# -p*log2*p

import math
def entropy(probs):  
    return sum( [-prob*math.log(prob, 2) for prob in probs])

#Function to calulate the entropy of the given Datasets/List with respect to target attributes
def entropy_of_list(ls,value):  
    from collections import Counter
    
    # Total intances associated with respective attribute
    total_instances = len(ls)  # = 14
    print("---------------------------------------------------------")
    print("\nTotal no of instances/records associated with '{0}' is ➡ {1}".format(value,total_instances))
    # Counter calculates the propotion of class
    cnt = Counter(x for x in ls)
    print('\nTarget attribute class count(Yes/No)=',dict(cnt))
    
    # x means no of YES/NO
    probs = [x / total_instances for x in cnt.values()]  
    print("\nClasses➡", max(cnt), min(cnt))
    print("\nProbabilities of Class 'p'='{0}' ➡ {1}".format(max(cnt),max(probs)))
    print("Probabilities of Class 'n'='{0}'  ➡ {1}".format(min(cnt),min(probs)))
    
    # Call Entropy 
    return entropy(probs)

# %%
def information_gain(df, split_attribute, target_attribute,battr):
    print("\n\n----- Information Gain Calculation of",split_attribute,"----- ") 
    
    # group the data based on attribute values
    df_split = df.groupby(split_attribute) 
    glist=[]
    for gname,group in df_split:
        print('Grouped Attribute Values \n',group)
        print("---------------------------------------------------------")
        glist.append(gname) 
    
    glist.reverse()
    nobs = len(df.index) * 1.0   
    df_agg1=df_split.agg({target_attribute:lambda x:entropy_of_list(x, glist.pop())})
    df_agg2=df_split.agg({target_attribute :lambda x:len(x)/nobs})
    
    df_agg1.columns=['Entropy']
    df_agg2.columns=['Proportion']
    
    # Calculate Information Gain:
    new_entropy = sum( df_agg1['Entropy'] * df_agg2['Proportion'])
    if battr !='S':
        old_entropy = entropy_of_list(df[target_attribute],'S-'+df.iloc[0][df.columns.get_loc(battr)])
    else:
        old_entropy = entropy_of_list(df[target_attribute],battr)
    return old_entropy - new_entropy

# %%
def id3(df, target_attribute, attribute_names, default_class=None,default_attr='S'):
    
    from collections import Counter
    cnt = Counter(x for x in df[target_attribute])# class of YES /NO
    
    ## First check: Is this split of the dataset homogeneous?
    if len(cnt) == 1:
        return next(iter(cnt))  # next input data set, or raises StopIteration when EOF is hit.
    
    ## Second check: Is this split of the dataset empty? if yes, return a default value
    elif df.empty or (not attribute_names):
        return default_class  # Return None for Empty Data Set
    
    ## Otherwise: This dataset is ready to be devied up!
    else:
        # Get Default Value for next recursive call of this function:
        default_class = max(cnt.keys()) #No of YES and NO Class
        # Compute the Information Gain of the attributes:
        gainz=[]
        for attr in attribute_names:
            ig= information_gain(df, attr, target_attribute,default_attr)
            gainz.append(ig)
            print('\nInformation gain of','“',attr,'”','is ➡', ig)
            print("=========================================================")
        
        index_of_max = gainz.index(max(gainz))               # Index of Best Attribute
        best_attr = attribute_names[index_of_max]            # Choose Best Attribute to split on
        print("\nList of Gain for arrtibutes:",attribute_names,"\nare:", gainz,"respectively.")
        print("\nAttribute with the maximum gain is ➡", best_attr)
        print("\nHence, the Root node will be ➡", best_attr)
        print("=========================================================")

        # Create an empty tree, to be populated in a moment
        tree = {best_attr:{}} # Initiate the tree with best attribute as a node 
        remaining_attribute_names =[i for i in attribute_names if i != best_attr]
        
        # Split dataset-On each split, recursively call this algorithm.Populate the empty tree with subtrees, which
        # are the result of the recursive call
        for attr_val, data_subset in df.groupby(best_attr):
            subtree = id3(data_subset,target_attribute, remaining_attribute_names,default_class,best_attr)
            tree[best_attr][attr_val] = subtree
        return tree

# %%
#Function to calulate the entropy of the given Dataset with respect to target attributes
def entropy_dataset(a_list):  
    from collections import Counter

    # Counter calculates the propotion of class
    cnt = Counter(x for x in a_list)   
    num_instances = len(a_list)*1.0    # = 14
    print("\nNumber of Instances of the Current Sub-Class is {0}".format(num_instances ))
    
    # x means no of YES/NO
    probs = [x / num_instances for x in cnt.values()]  
    print("\nClasses➡", "'p'=",max(cnt), "'n'=",min(cnt))
    print("\nProbabilities of Class 'p'='{0}' ➡ {1}".format(max(cnt),max(probs)))
    print("Probabilities of Class 'n'='{0}'  ➡ {1}".format(min(cnt),min(probs)))
    
    # Call Entropy
    return entropy(probs) 
    
# The initial entropy of the YES/NO attribute for our dataset.
print("Entropy calculation for input dataset:\n")
print(df['Select'])

total_entropy = entropy_dataset(df['Select'])
print("\nTotal Entropy(S) of  Dataset➡", total_entropy)
print("=========================================================")
####################################################

from pprint import pprint
tree = id3(df,t,attribute_names)
print("\nThe Resultant Decision Tree is: ⤵\n")
pprint(tree)

attribute = next(iter(tree))
print("\nBest Attribute ➡",attribute)
print("Tree Keys      ➡",tree[attribute].keys())
# Out:
# Entropy calculation for input dataset:
#
# 0     N
# 1     N
# 2     Y
# 3     Y
# 4     Y
# 5     N
# 6     Y
# 7     N
# 8     Y
# 9     Y
# 10    Y
# 11    Y
# 12    Y
# 13    N
# Name: Select, dtype: object
#
# Number of Instances of the Current Sub-Class is 14.0
#
# Classes➡ 'p'= Y 'n'= N
#
# Probabilities of Class 'p'='Y' ➡ 0.6428571428571429
# Probabilities of Class 'n'='N'  ➡ 0.35714285714285715
#
# Total Entropy(S) of  Dataset➡ 0.9402859586706309
# =========================================================
#
#
# ----- Information Gain Calculation of Age -----
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 2    M      H   P           A      Y
# 6    M      L   G           E      Y
# 11   M      M   P           E      Y
# 12   M      H   G           A      Y
# ---------------------------------------------------------
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 3    O      M   P           A      Y
# 4    O      L   G           A      Y
# 5    O      L   G           E      N
# 9    O      M   G           A      Y
# 13   O      M   P           E      N
# ---------------------------------------------------------
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 0    Y      H   P           A      N
# 1    Y      H   P           E      N
# 7    Y      M   P           A      N
# 8    Y      L   G           A      Y
# 10   Y      M   G           E      Y
# ---------------------------------------------------------
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'M' is ➡ 4
#
# Target attribute class count(Yes/No)= {'Y': 4}
#
# Classes➡ Y Y
#
# Probabilities of Class 'p'='Y' ➡ 1.0
# Probabilities of Class 'n'='Y'  ➡ 1.0
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'O' is ➡ 5
#
# Target attribute class count(Yes/No)= {'Y': 3, 'N': 2}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6
# Probabilities of Class 'n'='N'  ➡ 0.4
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'Y' is ➡ 5
#
# Target attribute class count(Yes/No)= {'N': 3, 'Y': 2}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6
# Probabilities of Class 'n'='N'  ➡ 0.4
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'S' is ➡ 14
#
# Target attribute class count(Yes/No)= {'N': 5, 'Y': 9}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6428571428571429
# Probabilities of Class 'n'='N'  ➡ 0.35714285714285715
#
# Information gain of “ Age ” is ➡ 0.2467498197744391
# =========================================================
#
#
# ----- Information Gain Calculation of Salary -----
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 0    Y      H   P           A      N
# 1    Y      H   P           E      N
# 2    M      H   P           A      Y
# 12   M      H   G           A      Y
# ---------------------------------------------------------
# Grouped Attribute Values
#    Age Salary Job Performance Select
# 4   O      L   G           A      Y
# 5   O      L   G           E      N
# 6   M      L   G           E      Y
# 8   Y      L   G           A      Y
# ---------------------------------------------------------
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 3    O      M   P           A      Y
# 7    Y      M   P           A      N
# 9    O      M   G           A      Y
# 10   Y      M   G           E      Y
# 11   M      M   P           E      Y
# 13   O      M   P           E      N
# ---------------------------------------------------------
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'H' is ➡ 4
#
# Target attribute class count(Yes/No)= {'N': 2, 'Y': 2}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.5
# Probabilities of Class 'n'='N'  ➡ 0.5
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'L' is ➡ 4
#
# Target attribute class count(Yes/No)= {'Y': 3, 'N': 1}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.75
# Probabilities of Class 'n'='N'  ➡ 0.25
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'M' is ➡ 6
#
# Target attribute class count(Yes/No)= {'Y': 4, 'N': 2}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6666666666666666
# Probabilities of Class 'n'='N'  ➡ 0.3333333333333333
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'S' is ➡ 14
#
# Target attribute class count(Yes/No)= {'N': 5, 'Y': 9}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6428571428571429
# Probabilities of Class 'n'='N'  ➡ 0.35714285714285715
#
# Information gain of “ Salary ” is ➡ 0.029222565658954647
# =========================================================
#
#
# ----- Information Gain Calculation of Job -----
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 4    O      L   G           A      Y
# 5    O      L   G           E      N
# 6    M      L   G           E      Y
# 8    Y      L   G           A      Y
# 9    O      M   G           A      Y
# 10   Y      M   G           E      Y
# 12   M      H   G           A      Y
# ---------------------------------------------------------
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 0    Y      H   P           A      N
# 1    Y      H   P           E      N
# 2    M      H   P           A      Y
# 3    O      M   P           A      Y
# 7    Y      M   P           A      N
# 11   M      M   P           E      Y
# 13   O      M   P           E      N
# ---------------------------------------------------------
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'G' is ➡ 7
#
# Target attribute class count(Yes/No)= {'Y': 6, 'N': 1}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.8571428571428571
# Probabilities of Class 'n'='N'  ➡ 0.14285714285714285
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'P' is ➡ 7
#
# Target attribute class count(Yes/No)= {'N': 4, 'Y': 3}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.5714285714285714
# Probabilities of Class 'n'='N'  ➡ 0.42857142857142855
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'S' is ➡ 14
#
# Target attribute class count(Yes/No)= {'N': 5, 'Y': 9}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6428571428571429
# Probabilities of Class 'n'='N'  ➡ 0.35714285714285715
#
# Information gain of “ Job ” is ➡ 0.15183550136234136
# =========================================================
#
#
# ----- Information Gain Calculation of Performance -----
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 0    Y      H   P           A      N
# 2    M      H   P           A      Y
# 3    O      M   P           A      Y
# 4    O      L   G           A      Y
# 7    Y      M   P           A      N
# 8    Y      L   G           A      Y
# 9    O      M   G           A      Y
# 12   M      H   G           A      Y
# ---------------------------------------------------------
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 1    Y      H   P           E      N
# 5    O      L   G           E      N
# 6    M      L   G           E      Y
# 10   Y      M   G           E      Y
# 11   M      M   P           E      Y
# 13   O      M   P           E      N
# ---------------------------------------------------------
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'A' is ➡ 8
#
# Target attribute class count(Yes/No)= {'N': 2, 'Y': 6}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.75
# Probabilities of Class 'n'='N'  ➡ 0.25
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'E' is ➡ 6
#
# Target attribute class count(Yes/No)= {'N': 3, 'Y': 3}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.5
# Probabilities of Class 'n'='N'  ➡ 0.5
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'S' is ➡ 14
#
# Target attribute class count(Yes/No)= {'N': 5, 'Y': 9}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6428571428571429
# Probabilities of Class 'n'='N'  ➡ 0.35714285714285715
#
# Information gain of “ Performance ” is ➡ 0.04812703040826927
# =========================================================
#
# List of Gain for arrtibutes: ['Age', 'Salary', 'Job', 'Performance']
# are: [0.2467498197744391, 0.029222565658954647, 0.15183550136234136, 0.04812703040826927] respectively.
#
# Attribute with the maximum gain is ➡ Age
#
# Hence, the Root node will be ➡ Age
# =========================================================
#
#
# ----- Information Gain Calculation of Salary -----
# Grouped Attribute Values
#    Age Salary Job Performance Select
# 4   O      L   G           A      Y
# 5   O      L   G           E      N
# ---------------------------------------------------------
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 3    O      M   P           A      Y
# 9    O      M   G           A      Y
# 13   O      M   P           E      N
# ---------------------------------------------------------
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'L' is ➡ 2
#
# Target attribute class count(Yes/No)= {'Y': 1, 'N': 1}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.5
# Probabilities of Class 'n'='N'  ➡ 0.5
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'M' is ➡ 3
#
# Target attribute class count(Yes/No)= {'Y': 2, 'N': 1}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6666666666666666
# Probabilities of Class 'n'='N'  ➡ 0.3333333333333333
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'S-O' is ➡ 5
#
# Target attribute class count(Yes/No)= {'Y': 3, 'N': 2}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6
# Probabilities of Class 'n'='N'  ➡ 0.4
#
# Information gain of “ Salary ” is ➡ 0.01997309402197489
# =========================================================
#
#
# ----- Information Gain Calculation of Job -----
# Grouped Attribute Values
#    Age Salary Job Performance Select
# 4   O      L   G           A      Y
# 5   O      L   G           E      N
# 9   O      M   G           A      Y
# ---------------------------------------------------------
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 3    O      M   P           A      Y
# 13   O      M   P           E      N
# ---------------------------------------------------------
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'G' is ➡ 3
#
# Target attribute class count(Yes/No)= {'Y': 2, 'N': 1}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6666666666666666
# Probabilities of Class 'n'='N'  ➡ 0.3333333333333333
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'P' is ➡ 2
#
# Target attribute class count(Yes/No)= {'Y': 1, 'N': 1}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.5
# Probabilities of Class 'n'='N'  ➡ 0.5
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'S-O' is ➡ 5
#
# Target attribute class count(Yes/No)= {'Y': 3, 'N': 2}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6
# Probabilities of Class 'n'='N'  ➡ 0.4
#
# Information gain of “ Job ” is ➡ 0.01997309402197489
# =========================================================
#
#
# ----- Information Gain Calculation of Performance -----
# Grouped Attribute Values
#    Age Salary Job Performance Select
# 3   O      M   P           A      Y
# 4   O      L   G           A      Y
# 9   O      M   G           A      Y
# ---------------------------------------------------------
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 5    O      L   G           E      N
# 13   O      M   P           E      N
# ---------------------------------------------------------
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'A' is ➡ 3
#
# Target attribute class count(Yes/No)= {'Y': 3}
#
# Classes➡ Y Y
#
# Probabilities of Class 'p'='Y' ➡ 1.0
# Probabilities of Class 'n'='Y'  ➡ 1.0
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'E' is ➡ 2
#
# Target attribute class count(Yes/No)= {'N': 2}
#
# Classes➡ N N
#
# Probabilities of Class 'p'='N' ➡ 1.0
# Probabilities of Class 'n'='N'  ➡ 1.0
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'S-O' is ➡ 5
#
# Target attribute class count(Yes/No)= {'Y': 3, 'N': 2}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6
# Probabilities of Class 'n'='N'  ➡ 0.4
#
# Information gain of “ Performance ” is ➡ 0.9709505944546686
# =========================================================
#
# List of Gain for arrtibutes: ['Salary', 'Job', 'Performance']
# are: [0.01997309402197489, 0.01997309402197489, 0.9709505944546686] respectively.
#
# Attribute with the maximum gain is ➡ Performance
#
# Hence, the Root node will be ➡ Performance
# =========================================================
#
#
# ----- Information Gain Calculation of Salary -----
# Grouped Attribute Values
#    Age Salary Job Performance Select
# 0   Y      H   P           A      N
# 1   Y      H   P           E      N
# ---------------------------------------------------------
# Grouped Attribute Values
#    Age Salary Job Performance Select
# 8   Y      L   G           A      Y
# ---------------------------------------------------------
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 7    Y      M   P           A      N
# 10   Y      M   G           E      Y
# ---------------------------------------------------------
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'H' is ➡ 2
#
# Target attribute class count(Yes/No)= {'N': 2}
#
# Classes➡ N N
#
# Probabilities of Class 'p'='N' ➡ 1.0
# Probabilities of Class 'n'='N'  ➡ 1.0
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'L' is ➡ 1
#
# Target attribute class count(Yes/No)= {'Y': 1}
#
# Classes➡ Y Y
#
# Probabilities of Class 'p'='Y' ➡ 1.0
# Probabilities of Class 'n'='Y'  ➡ 1.0
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'M' is ➡ 2
#
# Target attribute class count(Yes/No)= {'N': 1, 'Y': 1}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.5
# Probabilities of Class 'n'='N'  ➡ 0.5
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'S-Y' is ➡ 5
#
# Target attribute class count(Yes/No)= {'N': 3, 'Y': 2}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6
# Probabilities of Class 'n'='N'  ➡ 0.4
#
# Information gain of “ Salary ” is ➡ 0.5709505944546686
# =========================================================
#
#
# ----- Information Gain Calculation of Job -----
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 8    Y      L   G           A      Y
# 10   Y      M   G           E      Y
# ---------------------------------------------------------
# Grouped Attribute Values
#    Age Salary Job Performance Select
# 0   Y      H   P           A      N
# 1   Y      H   P           E      N
# 7   Y      M   P           A      N
# ---------------------------------------------------------
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'G' is ➡ 2
#
# Target attribute class count(Yes/No)= {'Y': 2}
#
# Classes➡ Y Y
#
# Probabilities of Class 'p'='Y' ➡ 1.0
# Probabilities of Class 'n'='Y'  ➡ 1.0
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'P' is ➡ 3
#
# Target attribute class count(Yes/No)= {'N': 3}
#
# Classes➡ N N
#
# Probabilities of Class 'p'='N' ➡ 1.0
# Probabilities of Class 'n'='N'  ➡ 1.0
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'S-Y' is ➡ 5
#
# Target attribute class count(Yes/No)= {'N': 3, 'Y': 2}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6
# Probabilities of Class 'n'='N'  ➡ 0.4
#
# Information gain of “ Job ” is ➡ 0.9709505944546686
# =========================================================
#
#
# ----- Information Gain Calculation of Performance -----
# Grouped Attribute Values
#    Age Salary Job Performance Select
# 0   Y      H   P           A      N
# 7   Y      M   P           A      N
# 8   Y      L   G           A      Y
# ---------------------------------------------------------
# Grouped Attribute Values
#     Age Salary Job Performance Select
# 1    Y      H   P           E      N
# 10   Y      M   G           E      Y
# ---------------------------------------------------------
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'A' is ➡ 3
#
# Target attribute class count(Yes/No)= {'N': 2, 'Y': 1}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6666666666666666
# Probabilities of Class 'n'='N'  ➡ 0.3333333333333333
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'E' is ➡ 2
#
# Target attribute class count(Yes/No)= {'N': 1, 'Y': 1}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.5
# Probabilities of Class 'n'='N'  ➡ 0.5
# ---------------------------------------------------------
#
# Total no of instances/records associated with 'S-Y' is ➡ 5
#
# Target attribute class count(Yes/No)= {'N': 3, 'Y': 2}
#
# Classes➡ Y N
#
# Probabilities of Class 'p'='Y' ➡ 0.6
# Probabilities of Class 'n'='N'  ➡ 0.4
#
# Information gain of “ Performance ” is ➡ 0.01997309402197489
# =========================================================
#
# List of Gain for arrtibutes: ['Salary', 'Job', 'Performance']
# are: [0.5709505944546686, 0.9709505944546686, 0.01997309402197489] respectively.
#
# Attribute with the maximum gain is ➡ Job
#
# Hence, the Root node will be ➡ Job
# =========================================================
#
# The Resultant Decision Tree is: ⤵
#
# {'Age': {'M': 'Y',
#          'O': {'Performance': {'A': 'Y', 'E': 'N'}},
#          'Y': {'Job': {'G': 'Y', 'P': 'N'}}}}
#
# Best Attribute ➡ Age
# Tree Keys      ➡ dict_keys(['M', 'O', 'Y'])
